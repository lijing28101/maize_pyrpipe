# %%
import os
import sys
from Bio import SeqIO
import pandas as pd
import seaborn as sns

#finction to calculate and return gc content
def getGC(seq):
    return((sum([1.0 for nucl in seq if nucl in ['G', 'C']]) / len(seq)) * 100)

# %%
#Read all the transcripts
all_tx='../transcripts.fa'
orphan_tx='../orphan_transcripts_final.fa'


orphan_sequences = SeqIO.parse(open(orphan_tx),'fasta')
orphan_ids=[]
orphan_len=[]
orphan_gc=[]
for fasta in orphan_sequences:
    name, sequence = fasta.id, str(fasta.seq)
    orphan_ids.append(name)


ids=[]
lens=[]
gc=[]
types=[]
all_sequences = SeqIO.parse(open(all_tx),'fasta')
for fasta in all_sequences:
    name, sequence = fasta.id, str(fasta.seq)
    ids.append(name)
    lens.append(len(sequence))
    gc.append(getGC(sequence))
    if name not in orphan_ids:
        types.append('Ancient')
    else:
        types.append('Orphan')

# %%
#get everything in pandas df
nest=[ids,lens,gc,types]

df=pd.DataFrame(nest, ['Name', 'len', 'gc','type']).T
df["len"]=pd.to_numeric(df["len"])
df["gc"]=pd.to_numeric(df["gc"])

#get all file names
from os import listdir
from os.path import isfile, join
dirpath='../quant'
quantfiles = [f for f in listdir(dirpath) if isfile(join(dirpath, f))]
for f in quantfiles:
    thisName=f.split("_")[0]
    fname=join(dirpath,f)
    print("reading:"+fname)
    q1=pd.read_csv(fname,sep='\t')
    #print(q1)
    thisQ=q1.loc[:,['Name','TPM']]
    thisQ["TPM"]=pd.to_numeric(thisQ["TPM"])
    thisQ.rename(columns = {'TPM':thisName+'_TPM'}, inplace = True) 
    #print(thisQ)
    #join with original df
    df=df.merge(thisQ,on='Name',how='left')
# Out:
# ['SRR1621015_quant.sf', 'SRR1620949_quant.sf', 'SRR3053545_quant.sf', 'SRR1573523_quant.sf', 'SRR1620828_quant.sf', 'SRR520999_quant.sf', 'SRR1620947_quant.sf', 'SRR1168424_quant.sf', 'SRR3084882_quant.sf', 'SRR999058_quant.sf']
# reading:../quant/SRR1621015_quant.sf
# reading:../quant/SRR1620949_quant.sf
# reading:../quant/SRR3053545_quant.sf
# reading:../quant/SRR1573523_quant.sf
# reading:../quant/SRR1620828_quant.sf
# reading:../quant/SRR520999_quant.sf
# reading:../quant/SRR1620947_quant.sf
# reading:../quant/SRR1168424_quant.sf
# reading:../quant/SRR3084882_quant.sf
# reading:../quant/SRR999058_quant.sf
#                 Name    len         gc     type  SRR1621015_TPM  \
# 0          MSTRG.1.1    154  38.961039  Ancient        0.000000
# 1          MSTRG.2.1     66  45.454545  Ancient        0.000000
# 2          MSTRG.3.1   1442  35.714286   Orphan        0.000000
# 3          MSTRG.4.1  18596  41.455152  Ancient        1.335344
# 4          MSTRG.5.1   5138  40.852472  Ancient       10.779823
# ...              ...    ...        ...      ...             ...
# 60994  MSTRG.36125.1    367  45.504087  Ancient     5835.887558
# 60995  MSTRG.36126.1     58  82.758621  Ancient        0.000000
# 60996  MSTRG.36127.1   9141  59.741823  Ancient        0.000000
# 60997  MSTRG.36128.1   9575  59.195822  Ancient        0.000000
# 60998  MSTRG.36129.1    117  52.991453   Orphan        0.000000
#
#        SRR1620949_TPM  SRR3053545_TPM  SRR1573523_TPM  SRR1620828_TPM  \
# 0            0.000000       79.893425        0.000000        0.000000
# 1            0.000000       40.149506        0.000000        0.000000
# 2            0.000000        0.220704        0.000000        0.000000
# 3            0.418622        0.558193        0.657155        0.827884
# 4           17.500333        2.482239        2.518733       12.500048
# ...               ...             ...             ...             ...
# 60994     3828.534071     1706.360803      865.664292    20204.776929
# 60995        0.000000        0.000000        0.000000        0.000000
# 60996        0.000000        0.000000        0.000000        0.272274
# 60997        0.000000        0.089865        0.000000        0.404945
# 60998        0.000000        0.000000        0.000000        0.000000
#
#        SRR520999_TPM  SRR1620947_TPM  SRR1168424_TPM  SRR3084882_TPM  \
# 0           0.000000        0.000000        0.000000        0.000000
# 1           0.000000        0.000000        0.000000        0.000000
# 2           0.000000        0.000000        0.465810        0.000000
# 3           0.248205        0.290867        2.134455        0.230102
# 4           1.302823       18.028387       10.076720        1.430789
# ...              ...             ...             ...             ...
# 60994       0.000000     2337.103191    72227.602814    15805.315303
# 60995       0.000000        0.000000        0.000000        0.000000
# 60996       0.000000        0.000000        0.000000        0.000000
# 60997       0.000000        0.000000        0.000000        0.000000
# 60998      67.295486        0.000000        0.000000        0.000000
#
#        SRR999058_TPM
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.294414
# 4           1.286988
# ...              ...
# 60994       0.000000
# 60995       0.000000
# 60996       0.000000
# 60997       0.438687
# 60998       0.000000
#
# [60999 rows x 14 columns]

# %%
#compare length distribution
print(df)
# Out:
#                 Name    len         gc     type  SRR1621015_TPM  \
# 0          MSTRG.1.1    154  38.961039  Ancient        0.000000
# 1          MSTRG.2.1     66  45.454545  Ancient        0.000000
# 2          MSTRG.3.1   1442  35.714286   Orphan        0.000000
# 3          MSTRG.4.1  18596  41.455152  Ancient        1.335344
# 4          MSTRG.5.1   5138  40.852472  Ancient       10.779823
# ...              ...    ...        ...      ...             ...
# 60994  MSTRG.36125.1    367  45.504087  Ancient     5835.887558
# 60995  MSTRG.36126.1     58  82.758621  Ancient        0.000000
# 60996  MSTRG.36127.1   9141  59.741823  Ancient        0.000000
# 60997  MSTRG.36128.1   9575  59.195822  Ancient        0.000000
# 60998  MSTRG.36129.1    117  52.991453   Orphan        0.000000
#
#        SRR1620949_TPM  SRR3053545_TPM  SRR1573523_TPM  SRR1620828_TPM  \
# 0            0.000000       79.893425        0.000000        0.000000
# 1            0.000000       40.149506        0.000000        0.000000
# 2            0.000000        0.220704        0.000000        0.000000
# 3            0.418622        0.558193        0.657155        0.827884
# 4           17.500333        2.482239        2.518733       12.500048
# ...               ...             ...             ...             ...
# 60994     3828.534071     1706.360803      865.664292    20204.776929
# 60995        0.000000        0.000000        0.000000        0.000000
# 60996        0.000000        0.000000        0.000000        0.272274
# 60997        0.000000        0.089865        0.000000        0.404945
# 60998        0.000000        0.000000        0.000000        0.000000
#
#        SRR520999_TPM  SRR1620947_TPM  SRR1168424_TPM  SRR3084882_TPM  \
# 0           0.000000        0.000000        0.000000        0.000000
# 1           0.000000        0.000000        0.000000        0.000000
# 2           0.000000        0.000000        0.465810        0.000000
# 3           0.248205        0.290867        2.134455        0.230102
# 4           1.302823       18.028387       10.076720        1.430789
# ...              ...             ...             ...             ...
# 60994       0.000000     2337.103191    72227.602814    15805.315303
# 60995       0.000000        0.000000        0.000000        0.000000
# 60996       0.000000        0.000000        0.000000        0.000000
# 60997       0.000000        0.000000        0.000000        0.000000
# 60998      67.295486        0.000000        0.000000        0.000000
#
#        SRR999058_TPM
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.294414
# 4           1.286988
# ...              ...
# 60994       0.000000
# 60995       0.000000
# 60996       0.000000
# 60997       0.438687
# 60998       0.000000
#
# [60999 rows x 14 columns]

# %%
#compare length
sns.set(font_scale=3)
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(14,11)})
ax = sns.violinplot(x="type", y="len", data=df)
ax.set_yscale("log")
ax.set_xlabel('Type',fontsize=35)
ax.set_ylabel('Length',fontsize=35)
# Out:
# Text(0, 0.5, 'Length')

# %%
#compare gc
ax = sns.violinplot(x="type", y="gc", data=df)
ax.set_xlabel('Type',fontsize=35);
ax.set_ylabel('GC%',fontsize=35);
